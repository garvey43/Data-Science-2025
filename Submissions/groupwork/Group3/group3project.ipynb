# %%
#prompt the user to write a sentence
sentence=input("Write a sentence")
sentence_nospace=(sentence.replace(" ", ""))
character_count=len(sentence_nospace)
word_count=len(sentence.split())
uppercase=sentence.upper()
lowercase=sentence.lower()
reversed = sentence[::-1]
print(f"Number of Characters:{character_count}")
print(f"Number of words:{word_count}")
print(f"Uppercase:{uppercase}")
print(f"Lowercase:{lowercase}")
print(f"Reversed:{reversed}")
# Out:
# Write a sentenceEldo    rec  tr
# Number of Characters:9
# Number of words:3
# Uppercase:ELDO    REC  TR
# Lowercase:eldo    rec  tr
# Reversed:rt  cer    odlE
