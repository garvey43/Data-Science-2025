# %%
#program to store secret integer
#prompt the user to guess the number
# Compares the guess to the secret and prints:
# “Too low” if the guess is less than the secret.
# “Too high” if the guess is greater.
# “Correct!” if the guess matches.
# Repeats until the user guesses correctly.
# Counts number of attempts and reports at the end.

secret_number=7
guess=0
attempt=0
#asks for the user to input another number if the guess is not correct,this process
#4is going to be repetitive if the user does not make a proper guess
try:

  while guess!=secret_number:
    try:
      attempt=attempt+1
      guess=int(input("Guess a number:"))
      if guess<secret_number:
        print("Too low")
      elif guess>secret_number:
        print("Too high")
      else:
        print("Correct!")

    except ValueError:
        print("Invalid input. Please enter a valid integer.")
  print(f"Attempts= {attempt}")
except KeyboardInterrupt:
        print("\nProgram terminated by the user.")
# Out:
# Guess a number:8
# Too high
#
# Program terminated by the user.

# %%
#Prompts the user to enter a full sentence.
sentence=input(f"enter a sentence:")

#Number of characters (excluding spaces)
characters=len(sentence.replace(" ",""))

#Number of words.
words=len(sentence.split())

#The sentence in uppercase and lowercase.
uppercase=sentence.upper()
lowercase=sentence.lower()


#The sentence reversed.
reversed=sentence[::-1]

#Outputs a formatted report using f-strings and aligned indentation.
print(f"sentence: {sentence}")
print(f"Number of characters: {characters}")
print(f"Number of words: {words}")
print(f"Uppercase: {uppercase}")
print(f"Lowercase: {lowercase}")
print(f"Reversed: {reversed}")
# Out:
# enter a sentence:fgf
# sentence: fgfn
# Number of characters: 3n
# Number of words: 1n
# Uppercase: FGFn
# Lowercase: fgfn

# %%
# 1.Which Python type holds textual data?
#      str
# 2.What does this expression return? len("Hi") +
#     len("Bye") * 2
# 3.Which of these is correct branching syntax?
#     int(input())
# 4.How do you convert user input into an integer safely?
#    	int(input())
