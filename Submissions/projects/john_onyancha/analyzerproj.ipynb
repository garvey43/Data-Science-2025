# %%
# 1.	String Analysis
# •	Counts: total characters, vowels, consonants, digits, and punctuation.
# •	Detects: the first and last occurrence of a user supplied substring.
# •	Lists: all unique words (case insensitive), sorted alphabetically.
# 2.	Numeric Statistics
# •	Accepts a comma separated list of integers from the user.
# •	Computes: sum, average (mean), minimum, and maximum using loops (no built ins like sum()).
# •	Flags: numbers divisible by 3 or 5, printing them with a label.
# 3.	Binary Converter
# •	Prompts the user for a positive or negative integer.
# •	Converts it to binary using the remainder division method (while loop), handling sign.
# •	Displays the binary string.
# 4.	Menu & Loop Control
# •	Presents a menu to the user to choose any of the above functions or exit.
# •	Uses a while True: loop with break/continue to manage the menu.

# Objectives for the Project
# •	Apply for loops to iterate over strings, lists, and ranges
# •	Use while loops for conditional repetition and number conversion.
# •	Employ break and continue to control loop flow.
# •	Implement nested loops for complex tasks (e.g., word extraction).
# •	Manage Boolean flags to detect conditions (e.g., substring found).
# •	Practice input/output and robust error handling.

while True:
    print(f"\n 1.Text Analysis\n 2.Number Analyzer \n 3.Binary Converter \n 4.exit")
    variable =int(input("enter your choice"))
    match variable:
        case 1:
            def analyze_text(text, substring):
                  # Counts
                total_chars = len(text)
                vowels = 'aeiouAEIOU'
                vowel_count=0
                consonant_count=0
                punctuation='!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
                punctuation_count=0
                digit_count=0

                for char in text:
                    if char in vowels:
                        vowel_count += 1


                for char in text:
                    if char.isalpha() and char not in vowels:
                        consonant_count += 1

                for char in text:
                    if char.isdigit():
                        digit_count += 1


                for char in text:
                    if char in punctuation:
                        punctuation_count += 1


                  # Substring Occurrences
                first_occurrence = text.find(substring)
                last_occurrence = text.rfind(substring)

                  # Unique Words
                words = text.lower().translate(str.maketrans('', '', punctuation)).split()
                unique_words = sorted(set(words))

              # Results
                result = {
                        "Total Characters": total_chars,
                        "Vowels": vowel_count,
                        "Consonants": consonant_count,
                        "Digits": digit_count,
                        "Punctuation Marks": punctuation_count,
                        "First Occurrence of Substring": first_occurrence,
                        "Last Occurrence of Substring": last_occurrence,
                        "Unique Words (Sorted)": unique_words
                    }

                return result

            # Example Usage
            text_input = input("Enter your text: ")
            substring_input = input("Enter the substring to search for: ")

            analysis = analyze_text(text_input, substring_input)

            # Display Results
            for key, value in analysis.items():
                print(f"{key}: {value}")


        case 2:
            def number_analyzer(num_list_str):
              # Convert input string to a list of integers
              num_list = []
              current_number = ""
              for i in num_list_str:
                  if i == ',':
                      if current_number != "":
                          num_list.append(int(current_number))
                          current_number = ""
                  else:
                      current_number += i
              if current_number != "":
                  num_list.append(int(current_number))

              # Initialize values
              total = 0
              count = 0
              min_val = num_list[0]
              max_val = num_list[0]
              dev3 = []
              dev5 = []

              # Loop to calculate sum, mean, min, max, and divisible numbers
              for i in num_list:
                  total += i
                  count += 1

                  if i < min_val:
                      min_val = i
                  if i > max_val:
                      max_val = i

                  if i % 3 == 0:
                      dev3.append(i)
                  if i % 5 == 0:
                      dev5.append(i)

              mean = total // count  # Integer division

              # Return results as a dictionary
              result = {
                  "sum": total,
                  "mean": mean,
                  "min": min_val,
                  "max": max_val,
                  "divisible by 3": dev3,
                  "divisible by 5": dev5
              }
              return result

            # Get user input and run analysis
            user_input = input("Enter numbers separated by commas: ")
            analysis = number_analyzer(user_input)

            # Display the results
            for key, value in analysis.items():
                print(f"{key}: {value}")
        case 3:
            def decimal_to_binary(decimal_num):
                if decimal_num == 0:
                    return "0"

                binary_string = ""
                while decimal_num > 0:
                    remainder = decimal_num % 2
                    binary_string = str(remainder) + binary_string
                    decimal_num //= 2
                return binary_string

            result=decimal_to_binary(abs(int(input("enter a positive or negative"))));
            print(result)
        case 4:
             break
# Out:
#  1.Text Analysis
#  2.Number Analyzer
#  3.Binary Converter
#  4.exit
# enter your choice2
# Enter numbers separated by commas: 12,90,89,90,67
# sum: 348
# mean: 69
# min: 12
# max: 90
# divisible by 3: [12, 90, 90]
# divisible by 5: [90, 90]
#
#  1.Text Analysis
#  2.Number Analyzer
#  3.Binary Converter
#  4.exit
# enter your choice3
# enter a positive or negative-90
# 1011010
#
#  1.Text Analysis
#  2.Number Analyzer
#  3.Binary Converter
#  4.exit
# enter your choice4

# %%
# 1.	String Analysis
# •	Counts: total characters, vowels, consonants, digits, and punctuation.
# •	Detects: the first and last occurrence of a user supplied substring.
# •	Lists: all unique words (case insensitive), sorted alphabetically.
# 2.	Numeric Statistics
# •	Accepts a comma separated list of integers from the user.
# •	Computes: sum, average (mean), minimum, and maximum using loops (no built ins like sum()).
# •	Flags: numbers divisible by 3 or 5, printing them with a label.
# 3.	Binary Converter
# •	Prompts the user for a positive or negative integer.
# •	Converts it to binary using the remainder division method (while loop), handling sign.
# •	Displays the binary string.
# 4.	Menu & Loop Control
# •	Presents a menu to the user to choose any of the above functions or exit.
# •	Uses a while True: loop with break/continue to manage the menu.

# Objectives for the Project
# •	Apply for loops to iterate over strings, lists, and ranges
# •	Use while loops for conditional repetition and number conversion.
# •	Employ break and continue to control loop flow.
# •	Implement nested loops for complex tasks (e.g., word extraction).
# •	Manage Boolean flags to detect conditions (e.g., substring found).
# •	Practice input/output and robust error handling.



def analyze_text(text, substring):
    # Counts
   total_chars = len(text)
   vowels = 'aeiouAEIOU'
   vowel_count=0
   consonant_count=0
   punctuation='!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
   punctuation_count=0
   digit_count=0

   for char in text:
       if char in vowels:
           vowel_count += 1


   for char in text:
       if char.isalpha() and char not in vowels:
           consonant_count += 1

   for char in text:
       if char.isdigit():
           digit_count += 1


   for char in text:
       if char in punctuation:
           punctuation_count += 1


    # Substring Occurrences
   first_occurrence = text.find(substring)
   last_occurrence = text.rfind(substring)

    # Unique Words
   words = text.lower().translate(str.maketrans('', '', punctuation)).split()
   unique_words = sorted(set(words))

    # Results
   result = {
        "Total Characters": total_chars,
        "Vowels": vowel_count,
        "Consonants": consonant_count,
        "Digits": digit_count,
        "Punctuation Marks": punctuation_count,
        "First Occurrence of Substring": first_occurrence,
        "Last Occurrence of Substring": last_occurrence,
        "Unique Words (Sorted)": unique_words
    }

   return result

# Example Usage
text_input = input("Enter your text: ")
substring_input = input("Enter the substring to search for: ")

analysis = analyze_text(text_input, substring_input)

# Display Results
for key, value in analysis.items():
    print(f"{key}: {value}")
# Out:
# Enter your text: eldohub is a good facility3,,,.
# Enter the substring to search for: is
# Total Characters: 31
# Vowels: 10
# Consonants: 12
# Digits: 1
# Punctuation Marks: 4
# First Occurrence of Substring: 8
# Last Occurrence of Substring: 8
# Unique Words (Sorted): ['a', 'eldohub', 'facility3', 'good', 'is']
