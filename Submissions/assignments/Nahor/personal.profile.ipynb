# %%
full_name = input("Full name")
age = int(input("Age"))
height = float(input("Height in centimeters"))
student = input("Are you  a student?a / not")
print(f"Hello {full_name},you are {age} years old, {height} cm tall and you are {student} student")
# Out:
# Full namenaho
# Age34
# Height in centimeters344
# Are you  a student?a / notnot
# Hello naho,you are 34 years old, 344.0 cm tall and you are not student

# %%
full_name =" Nahor kipruto"
age = 17
height = 177
student = False
print(f"Hello {full_name},you are {age} years old, {height} cm tall and you're student status is {student}")
# Out:
# Hello  Nahor kipruto,you are 17 years old, 177 cm tall and you're student status is False
