# %%
# Challenge 2: Using sum() and len() with Lists
# Problem A: Find the average of a list of numbers (10 marks)
# Function Signature:
def average(L):
    tl = sum(L)
    co = len(L)
    r = tl / co
    return r

my_list = [4, 8, 10, 6]
print("Average is:", average(my_list))

# %%
| Benefit         | Programming             | Real-Life Analogy                        |
| --------------- | ----------------------- | ---------------------------------------- |
| **Organize**    | Break code into parts   | Organize tasks (e.g., meal prep steps)   |
| **Reuse**       | Call function anywhere  | Use same tool/routine repeatedly         |
| **Abstract**    | Hide complex logic      | Use appliances without wiring knowledge  |
| **Debug/Test**  | Isolate failures easily | Fix one recipe step without remaking all |
| **Maintain**    | Update code once        | Change alarm time setting once           |
| **Collaborate** | Teams work modularly    | Departments handling separate duties     |

# %%
#Problem B: Find the total number of letters in a list of strings(10 Marks)
#Function Signature:
def total_(words):
    total = 0
    for word in words:
        total += len(word)
    return total
my_list = ["Ngwashe", "Uji", "Matoke"]
print("Total letters:", total_(my_list))

# %%
# Challenge 3: Combine Lambda + List(10 Marks)
# Problem:
# Use filter() and a lambda to return all numbers divisible by 3 in a list.
#My numbers
numbers = [3, 4, 6, 8, 9]

# Filter with lambda to GET numbers div3
div3 = filter(lambda number: number % 3 == 0, numbers)

# Convert & print it
print("Numbers divisible by 3:", list(div3))
