# %%
# Program to Input and Display the outcome from the User
# Student Input Details
Student_name = input("Enter Your Two Names:")
Age = abs(int(input("Enter Your Age:")))
# Display message
Output = f"Welcome {Student_name} so much, Your are {Age} years old."
# Print the outcome
print(Output)
# Out:
# Enter Your Two Names:CVB SDF
# Enter Your Age:-78
# Welcome CVB SDF so much, Your are 78 years old.
