# %%
# 1.	Prompt the user:
# num_str = input("Enter a positive integer: ")
# 2.	Validate input is all digits (str.isdigit())
# 3.	Initialize a dictionary counts = {}.
# 4.	Iterate over each character in the string (for ch in num_str:) :
# •	Convert ch to an integer if desired, or keep as string key.
# •	Use counts[ch] = counts.get(ch, 0) + 1.
# 5.	After the loop, print each digit and its frequency in ascending order:

num_str = input("Enter a positive integer : ")
if num_str.isdigit():
    counts = {}
    for ch in num_str:
        counts[ch] = counts.get(ch, 0) + 1

    for key in sorted(counts):
        print(key, counts[key])
else:
    print("Invalid input. Please enter a positive integer.")
# Out:
# Enter a positive integer : 566663444
# 3 1
# 4 3
# 5 1
# 6 4

# %%
# 1.	Import the built in random module.
# 2.	Generate a random integer between 1 and 50:
#3.	Set a counter attempts = 0 and a maximum max_attempts = 5.
#4.	Use a while loop (while attempts < max_attempts:) to allow up to 5 guesses:
#5.	After the loop, if the user didn’t guess correctly
import random
attempts = 5

secret_number = random.randint(1, 50)
print("I'm thinking a number between 1 and 50. Try to guess it.")
print("You have 5 attempts")
print("Good luck!")
print()
print("Lets start!")
print()

while attempts > 0:
  guess = input("Enter your guess: ")

  if not guess.isdigit():
    print("Invalid input.please enter a number.")
    continue

  guess = int(guess)

  if guess < 1 or guess > 50:
    print("Your guess is out of range.please enter a number between 1 and 50.")
    continue

  if guess == secret:
    print("Correct!You guessed the number!")
    break

  elif guess < secret:
    print("Too low.Try again.")
  else:
    print("Too high.Try again.")

  attempts -= 1
  if attempts > 0:
    print(f"You have {attempts} attempts left.")
  else:
    print(f"Sorry you've run out of attempts.The number was {secret_number}")
# Out:
# I'm thinking a number between 1 and 50. Try to guess it.
# You have 5 attempts
# Good luck!
#
# Lets start!
#
# Enter your guess: 49
# Too high.Try again.
# You have 4 attempts left.
# Enter your guess: 25
# Too low.Try again.
# You have 3 attempts left.
# Enter your guess: 40
# Too low.Try again.
# You have 2 attempts left.
# Enter your guess: 46
# Too high.Try again.
# You have 1 attempts left.
# Enter your guess: 34
# Too low.Try again.
# Sorry you've run out of attempts.The number was 48
