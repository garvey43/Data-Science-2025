# %%
#a program that asks for a student name and age and prints a welcome message containing the name and age

#ask for username and age
name=input("Enter your name: ")
age=int(input("Enter your age: "))


print(f"Welcome {name}, you are {age} years old.")
# Out:
# Enter your name: john
# Enter your age: 67
# Welcome john, you are 67 years old.
