# %%
# Final Assignment Topic 4
# Assignment 1: Binary Name Tag Generator (For Loop + ASCII
# + Binary)
# Scenario
# Your mission: help your classmates get awesome binary name tags.
# Each student should input their first name, and your program will display:
# 1. Each letter
# 2. Its ASCII code
# 3. Its 8-bit binary value
# Instructions
# 1. Ask the user to enter their first name.
# 2. For each character:
# • Convert to ASCII using ord()
# • Convert ASCII to binary using format(..., '08b')
# 3. Print the result nicely.
# Sample Output
#     Code Output:
# Name: ZOE
# Z → 90 → 01011010
# O → 79 → 01001111
# E → 69 → 01000101

# %%
first_name = input("Enter your first name: ")
for letter in first_name:
    ascii_code = ord(letter)
    binary_value = format(ascii_code, '08b')
    print(f"{letter} → {ascii_code} → {binary_value}")
# Out:
# Enter your first name: john
# j → 106 → 01101010
# o → 111 → 01101111
# h → 104 → 01101000
# n → 110 → 01101110

# %%
# Assignment 2: Secret Binary Door Unlocker (Guess-and-Check
# + Binary + Loops)
# Scenario
# There's a secret door in your program, and it only opens when the correct code in binary is entered.
# The user must guess the decimal number hidden behind the binary code using guess-and-check logic.
# Instructions
# 1. The program stores a secret binary string, like '1011' (which is 11).
# 2. The user must guess the decimal number.
# 3. Your program checks if the guess converted to binary matches the secret.
# 4. Loop until the user guesses right, then print "Door Unlocked!".
# Code Output:
# Binary Door Code Challenge!
# Guess the number that matches the secret binary code: 1011
# Your guess: 8
# Binary of 8 → 1000 → Not a match.
# Your guess: 11
# Binary of 11 → 1011 → Door Unlnlocked

guess='1011'

while True:
    user_guess = int(input("Guess the number that matches the secret binary code: "))
    binary_guess = format(user_guess, '04b')
    print(f"Binary of {user_guess} → {binary_guess}")
    if binary_guess == guess:
        print("Door Unlocked!")
        break
# Out:
# Guess the number that matches the secret binary code: 8
# Binary of 8 → 1000
# Guess the number that matches the secret binary code: 9
# Binary of 9 → 1001
# Guess the number that matches the secret binary code: 80
# Binary of 80 → 1010000
# Guess the number that matches the secret binary code: 11
# Binary of 11 → 1011
# Door Unlocked!

# %%
#initialize the guess binary value
guess='1011'

#declare a nested while loop for checking if guess is equall to user input and converting userinput to binary respectively
while True:
    user_guess = int(input("Guess the number that matches the secret binary code: "))
    #declare an empty string to be updated during the binary conversion
    binary_guess = ''
    user_guess2=user_guess
    while user_guess>0:
      remainder=user_guess%2
      binary_guess=str(remainder)+binary_guess
      user_guess=user_guess//2
    print(f"Binary of {user_guess2} → {binary_guess}")

    #check if binary guess is similar to the guess

    if binary_guess == guess:
        print("Door Unlocked!")
        break
# Out:
# Guess the number that matches the secret binary code: 8
# Binary of 8 → 1000
# Guess the number that matches the secret binary code: 9
# Binary of 9 → 1001
# Guess the number that matches the secret binary code: 11
# Binary of 11 → 1011
# Door Unlocked!
