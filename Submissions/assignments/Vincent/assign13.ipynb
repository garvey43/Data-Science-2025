# %%
def safe_average(L):
    """
    L is a list of numbers (ints or floats). It may be empty or contain non-numeric values.
    Returns the average of all valid numeric elements in the list.
    Ignores non-numeric items using exception handling.
    Raises a ValueError if there are no numeric elements.
    """
    total = 0
    count = 0

    for item in L:
        try:
            num = float(item)
            total += num
            count += 1
        except (ValueError, TypeError):
            continue

    if count == 0:
        raise ValueError("No numeric values found in the list.")

    return total / count

# 🧪 Example Tests
print(safe_average([10, 20, "thirty", 40]))  # ➜ 23.333...
# print(safe_average(["a", "b"]))            # ➜ raises ValueError

# %%
def student_score_summary(scores, threshold):
    """
    Returns a list of student names whose scores are above the threshold.
    Sorted alphabetically.
    """
    above_threshold = [name for name, score in scores.items() if score > threshold]
    return sorted(above_threshold)

# 🧪 Example Tests
students = {"Alice": 85, "Bob": 92, "Charlie": 78, "Daisy": 95}
print(student_score_summary(students, 80))   # ➜ ['Alice', 'Bob', 'Daisy']
print(student_score_summary(students, 100))  # ➜ []

# %%
def student_score_summary(scores, threshold):
    """
    Returns a list of student names whose scores are above the threshold.
    Sorted alphabetically.
    """
    above_threshold = [name for name, score in scores.items() if score > threshold]
    return sorted(above_threshold)

# 🧪 Example Tests
students = {"Alice": 85, "Bob": 92, "Charlie": 78, "Daisy": 95}
print(student_score_summary(students, 80))   # ➜ ['Alice', 'Bob', 'Daisy']
print(student_score_summary(students, 100))  # ➜ []

# %%
def merge_inventory(inv1, inv2):
    """
    Combines two inventories (dictionaries). If items overlap, their quantities are summed.
    Returns a new merged dictionary.
    """
    merged = inv1.copy()  # Start with inv1

    for item, qty in inv2.items():
        if item in merged:
            merged[item] += qty
        else:
            merged[item] = qty

    return merged

# 🧪 Example Tests
inv1 = {"pen": 10, "notebook": 5}
inv2 = {"notebook": 3, "eraser": 7}
print(merge_inventory(inv1, inv2))  # ➜ {'pen': 10, 'notebook': 8, 'eraser': 7}
