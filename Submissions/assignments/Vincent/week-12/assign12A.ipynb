# %%
def greet(name, greeting="Hello"):
    print(f"{greeting}, {name}!")

# 🧪 Example usage:
greet("Alice")                      # ➜ Hello, Alice!
greet("Bob", greeting="Hi")        # ➜ Hi, Bob!
greet(name="Clara", greeting="Yo") # ➜ Yo, Clara!

# %%
squares = []
for x in range(10):
    squares.append(x ** 2)

# %%
evens = [x for x in range(20) if x % 2 == 0]
print(evens)  # ➜ [0, 2, 4, ..., 18]
