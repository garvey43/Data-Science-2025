# %%
# inputs user details
users_name= input("whats your name? ")
age =  abs(int(input("Enter age? ")))

#prints a welcome message to the user
message = f"welcome {users_name}, you are {age} years old"
print(message)

# asks the user to enter a random number
number =int(input("Enter number? "))

# checks the status of the number and displays the output

if number > 0:
  print("Positive")

elif number < 0:
  print("Negative")

elif number == 0:
  print("Zero")
