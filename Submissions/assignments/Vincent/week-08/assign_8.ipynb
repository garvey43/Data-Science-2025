# %%
# Lambda function to check if a number is a multiple of 3
is_multiple_of_3 = lambda x: x % 3 == 0

#  Example
print(is_multiple_of_3(9))   # True
print(is_multiple_of_3(10))  # False
# Out:
# True
# False

# %%
numbers = [1, 3, 6, 8, 9, 12, 14, 15]
div_by_3 = list(filter(lambda x: x % 3 == 0, numbers))

#  Example
print(div_by_3)  # [3, 6, 9, 12, 15]
# Out:
# [3, 6, 9, 12, 15]

# %%
def average(L):
    if not L:
        return 0
    return sum(L) / len(L)

# 🧪 Example
print(average([10, 20, 30]))  # 20.0
# Out:
# 20.0

# %%
def total_letters(words):
    return sum(len(word) for word in words)

# 🧪 Example
print(total_letters(["hello", "world"]))  # 10
# Out:
# 10

# %%
def dot_product(tA, tB):
    """
    tA: a tuple of numbers
    tB: a tuple of numbers of the same length as tA
    Returns a tuple (length, dot product of tA and tB)
    """
    total = 0
    for i in range(len(tA)):
        total += tA[i] * tB[i]
    return (len(tA), total)

# 🧪 Example:
print(dot_product((1, 2, 3), (4, 5, 6)))  # ➜ (3, 32)
# Out:
# (3, 32)
